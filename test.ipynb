# %%
import pandas as pd

codes = ['A','B','D','H','L','P','R','V']
df = pd.concat([pd.read_csv(f'data/raw/ddinter_downloads_code_{c}.csv') for c in codes])

# Search both name columns case-insensitively for anything containing "aspir" or "acetylsalicylic"
mask = (
    df['Drug_A'].str.contains('aspir|acetylsalicylic', case=False, na=False) |
    df['Drug_B'].str.contains('aspir|acetylsalicylic', case=False, na=False)
)
matches = pd.concat([df.loc[mask, 'Drug_A'], df.loc[mask, 'Drug_B']]).unique()
print(matches)

print('Aspirin' in matches)
print('Acetylsalicylic acid' in matches)
# Out:
# <ArrowStringArray>
# [              'Abciximab',    'Acetylsalicylic acid',
#                 'Caffeine',           'Acetazolamide',
#                'Ketorolac',  'Ketorolac (ophthalmic)',
#           'Hydrocortisone',                 'Ethanol',
#          'Alendronic acid',             'Fluvoxamine',
#  ...
#               'Salbutamol',                'Abacavir',
#              'Amoxicillin',              'Amiodarone',
#               'Amifostine',               'Bupropion',
#              'Anastrozole', 'gamma-Aminobutyric acid',
#           'Acetylcysteine',               'Galactose']
# Length: 655, dtype: str
# False
# True

# %%
import requests

url = "https://ddinter.scbdd.com/ddinter/grapher-datasource/DDInter690/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36",
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "X-Requested-With": "XMLHttpRequest",
    "Referer": "https://ddinter.scbdd.com/ddinter/drug-detail/DDInter690/"
}

r = requests.get(url, headers=headers, timeout=15)

print("Status:", r.status_code)
print("Content-Type:", r.headers.get("content-type"))
print("Response preview:")
print(r.text[:1000])
# Out:
# Status: 200
# Content-Type: application/json
# Response preview:
# {"info": {"id": "DDInter690", "Name": "Ethanol"}, "interactions": [{"id": "DDInter81", "name": "Amobarbital", "level": ["Major"], "actions": ["metabolism"]}, {"id": "DDInter183", "name": "Benznidazole", "level": ["Major"], "actions": ["metabolism"]}, {"id": "DDInter251", "name": "Buprenorphine", "level": ["Major"], "actions": ["synergy"]}, {"id": "DDInter632", "name": "Eluxadoline", "level": ["Major"], "actions": ["others"]}, {"id": "DDInter741", "name": "Flibanserin", "level": ["Major"], "actions": ["synergy"]}, {"id": "DDInter773", "name": "Fomepizole", "level": ["Major"], "actions": ["metabolism"]}, {"id": "DDInter884", "name": "Hydrocodone", "level": ["Major"], "actions": ["synergy"]}, {"id": "DDInter1033", "name": "Leflunomide", "level": ["Major"], "actions": ["synergy"]}, {"id": "DDInter1043", "name": "Levacetylmethadol", "level": ["Major"], "actions": ["synergy"]}, {"id": "DDInter1085", "name": "Lomitapide", "level": ["Major"], "actions": ["synergy"]}, {"id": "DDInter1202", "nam
